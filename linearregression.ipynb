# %%
import pandas as pd

# %%
df = pd.read_csv("./CourseDataset.csv")

# %%
df.head()
# Out:
#    Crime_Rate  Land_Size  Business_Land  River_Boundary  Air_Quality  \
# 0     0.00632       18.0           2.31               0        0.538
# 1     0.02731        0.0           7.07               0        0.469
# 2     0.02729        0.0           7.07               0        0.469
# 3     0.03237        0.0           2.18               0        0.458
# 4     0.06905        0.0           2.18               0        0.458
#
#    Number_of_Rooms  Age_of_Homes  Distance_to_Work  Highway_Access  \
# 0            6.575          65.2            4.0900               1
# 1            6.421          78.9            4.9671               2
# 2            7.185          61.1            4.9671               2
# 3            6.998          45.8            6.0622               3
# 4            7.147          54.2            6.0622               3
#
#    Property_Tax  School_Quality  Population_Status  Home_Value
# 0           296            15.3               4.98        24.0
# 1           242            17.8               9.14        21.6
# 2           242            17.8               4.03        34.7
# 3           222            18.7               2.94        33.4
# 4           222            18.7               5.33        36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Crime_Rate         506 non-null    float64
#  1   Land_Size          506 non-null    float64
#  2   Business_Land      506 non-null    float64
#  3   River_Boundary     506 non-null    int64
#  4   Air_Quality        506 non-null    float64
#  5   Number_of_Rooms    506 non-null    float64
#  6   Age_of_Homes       506 non-null    float64
#  7   Distance_to_Work   506 non-null    float64
#  8   Highway_Access     506 non-null    int64
#  9   Property_Tax       506 non-null    int64
#  10  School_Quality     506 non-null    float64
#  11  Population_Status  506 non-null    float64
#  12  Home_Value         506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
summary_statistics = df.describe()
print(summary_statistics)
# Out:
#        Crime_Rate   Land_Size  Business_Land  River_Boundary  Air_Quality  \
# count  506.000000  506.000000     506.000000      506.000000   506.000000
# mean     3.613524   11.363636      11.136779        0.069170     0.554695
# std      8.601545   23.322453       6.860353        0.253994     0.115878
# min      0.006320    0.000000       0.460000        0.000000     0.385000
# 25%      0.082045    0.000000       5.190000        0.000000     0.449000
# 50%      0.256510    0.000000       9.690000        0.000000     0.538000
# 75%      3.677083   12.500000      18.100000        0.000000     0.624000
# max     88.976200  100.000000      27.740000        1.000000     0.871000
#
#        Number_of_Rooms  Age_of_Homes  Distance_to_Work  Highway_Access  \
# count       506.000000    506.000000        506.000000      506.000000
# mean          6.284634     68.574901          3.795043        9.549407
# std           0.702617     28.148861          2.105710        8.707259
# min           3.561000      2.900000          1.129600        1.000000
# 25%           5.885500     45.025000          2.100175        4.000000
# 50%           6.208500     77.500000          3.207450        5.000000
# 75%           6.623500     94.075000          5.188425       24.000000
# max           8.780000    100.000000         12.126500       24.000000
#
#        Property_Tax  School_Quality  Population_Status  Home_Value
# count    506.000000      506.000000         506.000000  506.000000
# mean     408.237154       18.455534          12.653063   22.532806
# std      168.537116        2.164946           7.141062    9.197104
# min      187.000000       12.600000           1.730000    5.000000
# 25%      279.000000       17.400000           6.950000   17.025000
# 50%      330.000000       19.050000          11.360000   21.200000
# 75%      666.000000       20.200000          16.955000   25.000000
# max      711.000000       22.000000          37.970000   50.000000

# %%
df.isna()
# Out:
#      Crime_Rate  Land_Size  Business_Land  River_Boundary  Air_Quality  \
# 0         False      False          False           False        False
# 1         False      False          False           False        False
# 2         False      False          False           False        False
# 3         False      False          False           False        False
# 4         False      False          False           False        False
# ..          ...        ...            ...             ...          ...
# 501       False      False          False           False        False
# 502       False      False          False           False        False
# 503       False      False          False           False        False
# 504       False      False          False           False        False
# 505       False      False          False           False        False
#
#      Number_of_Rooms  Age_of_Homes  Distance_to_Work  Highway_Access  \
# 0              False         False             False           False
# 1              False         False             False           False
# 2              False         False             False           False
# 3              False         False             False           False
# 4              False         False             False           False
# ..               ...           ...               ...             ...
# 501            False         False             False           False
# 502            False         False             False           False
# 503            False         False             False           False
# 504            False         False             False           False
# 505            False         False             False           False
#
#      Property_Tax  School_Quality  Population_Status  Home_Value
# 0           False           False              False       False
# 1           False           False              False       False
# 2           False           False              False       False
# 3           False           False              False       False
# 4           False           False              False       False
# ..            ...             ...                ...         ...
# 501         False           False              False       False
# 502         False           False              False       False
# 503         False           False              False       False
# 504         False           False              False       False
# 505         False           False              False       False
#
# [506 rows x 13 columns]

# %%
df.isnull()
# Out:
#      Crime_Rate  Land_Size  Business_Land  River_Boundary  Air_Quality  \
# 0         False      False          False           False        False
# 1         False      False          False           False        False
# 2         False      False          False           False        False
# 3         False      False          False           False        False
# 4         False      False          False           False        False
# ..          ...        ...            ...             ...          ...
# 501       False      False          False           False        False
# 502       False      False          False           False        False
# 503       False      False          False           False        False
# 504       False      False          False           False        False
# 505       False      False          False           False        False
#
#      Number_of_Rooms  Age_of_Homes  Distance_to_Work  Highway_Access  \
# 0              False         False             False           False
# 1              False         False             False           False
# 2              False         False             False           False
# 3              False         False             False           False
# 4              False         False             False           False
# ..               ...           ...               ...             ...
# 501            False         False             False           False
# 502            False         False             False           False
# 503            False         False             False           False
# 504            False         False             False           False
# 505            False         False             False           False
#
#      Property_Tax  School_Quality  Population_Status  Home_Value
# 0           False           False              False       False
# 1           False           False              False       False
# 2           False           False              False       False
# 3           False           False              False       False
# 4           False           False              False       False
# ..            ...             ...                ...         ...
# 501         False           False              False       False
# 502         False           False              False       False
# 503         False           False              False       False
# 504         False           False              False       False
# 505         False           False              False       False
#
# [506 rows x 13 columns]

# %%
df.columns.value_counts()
# Out:
# Crime_Rate           1
# Land_Size            1
# Business_Land        1
# River_Boundary       1
# Air_Quality          1
# Number_of_Rooms      1
# Age_of_Homes         1
# Distance_to_Work     1
# Highway_Access       1
# Property_Tax         1
# School_Quality       1
# Population_Status    1
# Home_Value           1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn in /Users/pramod/miniconda3/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
for i in df.columns:
    print(i)
    plt.figure(figsize = (7,7))
    sns.histplot(data=df, x=i, kde = True)
    plt.show()
# Out:
# Crime_Rate
# Land_Size
# Business_Land
# River_Boundary
# Air_Quality
# Number_of_Rooms
# Age_of_Homes
# Distance_to_Work
# Highway_Access
# Property_Tax
# School_Quality
# Population_Status
# Home_Value

# %%
df.columns
# Out:
# Index(['Crime_Rate', 'Land_Size', 'Business_Land', 'River_Boundary',
#        'Air_Quality', 'Number_of_Rooms', 'Age_of_Homes', 'Distance_to_Work',
#        'Highway_Access', 'Property_Tax', 'School_Quality', 'Population_Status',
#        'Home_Value'],
#       dtype='object')

# %%
import numpy as np

# %%
df['Home_Value_log'] = np.log(df['Home_Value'])

# %%
sns.histplot(data = df, x = 'Home_Value_log', kde = True)
# Out:
# <Axes: xlabel='Home_Value_log', ylabel='Count'>

# %%
plt.figure(figsize = (12,8)) 
sns.scatterplot(x = , y = , data = df)
# Out:
#   Cell In[112], line 2
#     sns.scatterplot(x = , y = , data = df)
#                     ^
# SyntaxError: expected argument value expression

# %%
plt.figure(figsize = (12,8))
cmap = sns.diverging_palette(230, 32, as_cmap=True)
sns.heatmap(data = df.corr(), annot = True, fmt = '.2f', cmap = cmap)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x =

# %%
df.columns

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x = 'Age_of_Homes', y = 'Distance_to_Work', data = df)
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = 'Highway_Access', y = 'Property_Tax', data = df)
plt.show()

# %%
df1 = df[df['Property_Tax'] < 600]

# %%
from scipy.stats import pearsonr

# %%
print('The correlation between', pearsonr(df1['Property_Tax'], df1['Highway_Access']).correlation)

# %%
df.columns

# %%
Y = df['Home_Value_log']
Y

# %%
X = df.drop(columns = {'Home_Value', 'Home_Value_log'})

# %%
# !pip install statsmodels

# %%
import statsmodels.api as sm
X = sm.add_constant(X)

# %%
X

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

## Function to check VIF
def checking_vif(train):
    vif = pd.DataFrame()
    vif["feature"] = train.columns

    vif["VIF"] = [
            variance_inflation_factor(train.values, i) for i in range(len(train.columns))
        ]

    return vif

print(checking_vif(X_train))

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Function to check VIF
def checking_vif(train):
    vif = pd.DataFrame()
    vif["feature"] = train.columns

    # Calculating VIF for each feature
    vif["VIF"] = [
        variance_inflation_factor(train.values, i) for i in range(len(train.columns))
    ]
    return vif


print(checking_vif(X_train))

# %%
X_train = X_train.drop('Property_Tax', axis=1)

# %%
print(checking_vif(X_train))

# %%
X_train

# %%
model = sm.OLS(Y_train, X_train).fit()
model.summary()

# %%
Y = df["Home_Value_log"]
X = df.drop(['Home_Value', 'Home_Value_log', 'Property_Tax', 'Land_Size', 'Age_of_Homes', 'Business_Land'], axis =1)
X = sm.add_constant(X)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state=1)
model2 = sm.OLS(y_train, X_train).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Home_Value_log   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     142.1
# Date:                Sun, 23 Mar 2025   Prob (F-statistic):          2.61e-104
# Time:                        13:58:25   Log-Likelihood:                 75.486
# No. Observations:                 354   AIC:                            -133.0
# Df Residuals:                     345   BIC:                            -98.15
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.6494      0.242     19.242      0.000       4.174       5.125
# Crime_Rate           -0.0125      0.002     -7.349      0.000      -0.016      -0.009
# River_Boundary        0.1198      0.039      3.093      0.002       0.044       0.196
# Air_Quality          -1.0562      0.168     -6.296      0.000      -1.386      -0.726
# Number_of_Rooms       0.0589      0.020      2.928      0.004       0.019       0.098
# Distance_to_Work     -0.0441      0.008     -5.561      0.000      -0.060      -0.028
# Highway_Access        0.0078      0.002      3.890      0.000       0.004       0.012
# School_Quality       -0.0485      0.006     -7.832      0.000      -0.061      -0.036
# Population_Status    -0.0293      0.002    -12.949      0.000      -0.034      -0.025
# ==============================================================================
# Omnibus:                       32.514   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.354
# Skew:                           0.408   Prob(JB):                     1.07e-19
# Kurtosis:                       5.293   Cond. No.                         690.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Create the model after dropping columns 'Home_Value', 'Home_Value_log', 'Property_Tax:', 'Land_Size', 'Age_of_Homes', 'Business_Land' from df DataFrame
Y = df['Home_Value_log']

X = df.drop(['Home_Value', 'Home_Value_log', 'Property_Tax', 'Land_Size', 'Age_of_Homes', 'Business_Land'], axis = 1)
X = sm.add_constant(X)

# Splitting the data in 70:30 ratio of train to test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30 , random_state = 1)

# Create the model
model2 = sm.OLS(y_train, X_train).fit()

# Get the model summary
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Home_Value_log   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     142.1
# Date:                Sun, 23 Mar 2025   Prob (F-statistic):          2.61e-104
# Time:                        13:57:55   Log-Likelihood:                 75.486
# No. Observations:                 354   AIC:                            -133.0
# Df Residuals:                     345   BIC:                            -98.15
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.6494      0.242     19.242      0.000       4.174       5.125
# Crime_Rate           -0.0125      0.002     -7.349      0.000      -0.016      -0.009
# River_Boundary        0.1198      0.039      3.093      0.002       0.044       0.196
# Air_Quality          -1.0562      0.168     -6.296      0.000      -1.386      -0.726
# Number_of_Rooms       0.0589      0.020      2.928      0.004       0.019       0.098
# Distance_to_Work     -0.0441      0.008     -5.561      0.000      -0.060      -0.028
# Highway_Access        0.0078      0.002      3.890      0.000       0.004       0.012
# School_Quality       -0.0485      0.006     -7.832      0.000      -0.061      -0.036
# Population_Status    -0.0293      0.002    -12.949      0.000      -0.034      -0.025
# ==============================================================================
# Omnibus:                       32.514   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.354
# Skew:                           0.408   Prob(JB):                     1.07e-19
# Kurtosis:                       5.293   Cond. No.                         690.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
residuals = model2.resid
np.mean(residuals)
# Out:
# np.float64(-2.2267184957171218e-15)

# %%
residuals = model2.resid
np.mean(residuals)
# Out:
# np.float64(-2.2267184957171218e-15)

# %%
from statsmodels.stats.diagnostic import het_white
from statsmodels.compat import lzip
import statsmodels.stats.api as sms

# %%
fitted = model2.fittedvalues
sns.residplot(x= fitted, y = y_train, color="lightblue", lowess=True)
plt.xlabel("Fitted Values")

plt.ylabel("Residual")

plt.title("Residual PLOT")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[129], line 2
#       1 fitted = model2.fittedvalues
# ----> 2 sns.residplot(x= fitted, y = y_train, color="lightblue", lowess=True)
#       3 plt.xlabel("Fitted Values")
#       5 plt.ylabel("Residual")
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:939, in residplot(data, x, y, x_partial, y_partial, lowess, order, robust, dropna, label, color, scatter_kws, line_kws, ax)
#     937 scatter_kws = {} if scatter_kws is None else scatter_kws.copy()
#     938 line_kws = {} if line_kws is None else line_kws.copy()
# --> 939 plotter.plot(ax, scatter_kws, line_kws)
#     940 return ax
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:384, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     381     self.scatterplot(ax, scatter_kws)
#     383 if self.fit_reg:
# --> 384     self.lineplot(ax, line_kws)
#     386 # Label the axes
#     387 if hasattr(self.x, "name"):
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:429, in _RegressionPlotter.lineplot(self, ax, kws)
#     427 """Draw the model."""
#     428 # Fit the regression model
# --> 429 grid, yhat, err_bands = self.fit_regression(ax)
#     430 edges = grid[0], grid[-1]
#     432 # Get set default aesthetics
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:198, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     196 def fit_regression(self, ax=None, x_range=None, grid=None):
#     197     """Fit the regression model."""
# --> 198     self._check_statsmodels()
#     200     # Create the grid for the regression
#     201     if grid is None:
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:194, in _RegressionPlotter._check_statsmodels(self)
#     192 for option in options:
#     193     if getattr(self, option) and not _has_statsmodels:
# --> 194         raise RuntimeError(err.format(option))
#
# RuntimeError: `lowess=True` requires statsmodels, an optional dependency, to be installed.

# %%
name = ["F statistic", "p-value"]
test = sms.het_goldfeldquandt(model2.resid, model2.model.exog)
lzip(name, test)
# Out:
# [('F statistic', np.float64(1.0835082923425292)),
#  ('p-value', np.float64(0.3019012006766846))]

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/pramod/miniconda3/lib/python3.12/site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from statsmodels) (2.0.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from statsmodels) (1.15.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/pramod/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
fitted = model2.fittedvalues
sns.residplot(x= fitted, y = y_train, color="lightblue", lowess=True)
plt.xlabel("Fitted Values")

plt.ylabel("Residual")

plt.title("Residual PLOT")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[131], line 2
#       1 fitted = model2.fittedvalues
# ----> 2 sns.residplot(x= fitted, y = y_train, color="lightblue", lowess=True)
#       3 plt.xlabel("Fitted Values")
#       5 plt.ylabel("Residual")
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:939, in residplot(data, x, y, x_partial, y_partial, lowess, order, robust, dropna, label, color, scatter_kws, line_kws, ax)
#     937 scatter_kws = {} if scatter_kws is None else scatter_kws.copy()
#     938 line_kws = {} if line_kws is None else line_kws.copy()
# --> 939 plotter.plot(ax, scatter_kws, line_kws)
#     940 return ax
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:384, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     381     self.scatterplot(ax, scatter_kws)
#     383 if self.fit_reg:
# --> 384     self.lineplot(ax, line_kws)
#     386 # Label the axes
#     387 if hasattr(self.x, "name"):
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:429, in _RegressionPlotter.lineplot(self, ax, kws)
#     427 """Draw the model."""
#     428 # Fit the regression model
# --> 429 grid, yhat, err_bands = self.fit_regression(ax)
#     430 edges = grid[0], grid[-1]
#     432 # Get set default aesthetics
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:198, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     196 def fit_regression(self, ax=None, x_range=None, grid=None):
#     197     """Fit the regression model."""
# --> 198     self._check_statsmodels()
#     200     # Create the grid for the regression
#     201     if grid is None:
#
# File ~/miniconda3/lib/python3.12/site-packages/seaborn/regression.py:194, in _RegressionPlotter._check_statsmodels(self)
#     192 for option in options:
#     193     if getattr(self, option) and not _has_statsmodels:
# --> 194         raise RuntimeError(err.format(option))
#
# RuntimeError: `lowess=True` requires statsmodels, an optional dependency, to be installed.

# %%
residuals = model2.resid
plt.hist(residuals, bins= 20)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Histogram of Residuals")
plt.show()

# %%
import pylab
import scipy.stats as stats
stats.probplot(residuals, dist = "norm", plot = pylab)

plt.show()

# %%
def rmse(predictions, targets):
    return np.sqrt(((targets-predictions)**2).mean())

# MAPE
def mape(predictions, targets):
    return np.mean(np.abs((targets - predictions)) / targets) * 100


# MAE
def mae(predictions, targets):
    return np.mean(np.abs((targets - predictions)))

def model_pref(olsmodel, x_train, x_test):

    # In-sample Prediction
    y_pred_train = olsmodel.predict(x_train)
    y_observed_train = y_train

    # Prediction on test data
    y_pred_test = olsmodel.predict(x_test)
    y_observed_test = y_test

    print(
        pd.DataFrame(
            {
                "Data": ["Train", "Test"],
                "RMSE": [
                    rmse(y_pred_train, y_observed_train),
                    rmse(y_pred_test, y_observed_test),
                ],
                "MAE": [
                    mae(y_pred_train, y_observed_train),
                    mae(y_pred_test, y_observed_test),
                ],
                "MAPE": [
                    mape(y_pred_train, y_observed_train),
                    mape(y_pred_test, y_observed_test),
                ],
            }
        )
    )


# Checking model performance
model_pref(model2, X_train, X_test)
# Out:
#     Data      RMSE       MAE      MAPE
# 0  Train  0.195504  0.143686  4.981813
# 1   Test  0.198045  0.151284  5.257965

# %%
# Import the required function
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# Build the regression model and cross-validate
linearregression = LinearRegression()                                    

cv_Score11 = cross_val_score(linearregression, X_train, y_train, cv = 10)
cv_Score12 = cross_val_score(linearregression, X_train, y_train, cv = 10, 
                             scoring = 'neg_mean_squared_error')                                  


print("RSquared: %0.3f (+/- %0.3f)" % (cv_Score11.mean(), cv_Score11.std() * 2))
print("Mean Squared Error: %0.3f (+/- %0.3f)" % (-1*cv_Score12.mean(), cv_Score12.std() * 2))
# Out:
# RSquared: 0.729 (+/- 0.232)
# Mean Squared Error: 0.041 (+/- 0.023)

# %%
coef = model2.params

pd.DataFrame({'Feature' : coef.index, 'Coefs' : coef.values})
# Out:
#              Feature     Coefs
# 0              const  4.649386
# 1         Crime_Rate -0.012500
# 2     River_Boundary  0.119773
# 3        Air_Quality -1.056225
# 4    Number_of_Rooms  0.058907
# 5   Distance_to_Work -0.044069
# 6     Highway_Access  0.007848
# 7     School_Quality -0.048504
# 8  Population_Status -0.029277

# %%
# Write the equation of the fit

Equation = "log (House Price) = "

print(Equation, end = '\t')

for i in range(len(coef)):
    print('(', coef[i], ') * ', coef.index[i], '+', end = ' ')
# Out:
# log (House Price) = 	( 4.649385823266632 ) *  const + ( -0.012500455079103665 ) *  Crime_Rate + ( 0.11977319077019909 ) *  River_Boundary + ( -1.0562253516683258 ) *  Air_Quality + ( 0.05890657510927967 ) *  Number_of_Rooms + ( -0.044068890799404924 ) *  Distance_to_Work + ( 0.007848474606243506 ) *  Highway_Access + ( -0.04850362079499866 ) *  School_Quality + ( -0.029277040479796682 ) *  Population_Status +
# /var/folders/lg/630xcy1549905qyg4k3dlhxw0000gn/T/ipykernel_10770/2516369459.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('(', coef[i], ') * ', coef.index[i], '+', end = ' ')
